# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
Data = pd.read_csv("Quantitative.csv", sep = ',')
print("Data : " + str(Data.shape))
Data.info()
Quantitative_scales = Data.select_dtypes(include=[np.number])
Quantitative_scales.columns
Data.describe()
# Out:
# Data : (1000, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
# Attr 4     1000 non-null float64
# Attr 5     1000 non-null float64
# Attr 6     1000 non-null float64
# Attr 7     1000 non-null float64
# Attr 8     1000 non-null float64
# Attr 9     1000 non-null float64
# Attr 10    1000 non-null float64
# Attr 11    1000 non-null float64
# Attr 12    1000 non-null float64
# dtypes: float64(9)
# memory usage: 70.4 KB
#             Attr 4       Attr 5       Attr 6       Attr 7       Attr 8  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.429506     4.096724     3.687289     0.022742     0.050446
# std       1.463489     3.488631     3.361178     0.934656     0.637652
# min      -3.256679    -2.560023    -0.509973    -2.612437    -0.892724
# 25%      -1.827079     2.249369     1.319508    -0.703916    -0.575071
# ...

# %%
Data.median()
# Out:
# Attr 4     -0.266172
# Attr 5      5.022662
# Attr 6      2.462706
# Attr 7      0.069515
# Attr 8      0.044942
# Attr 9      0.044942
# Attr 10     0.044942
# Attr 11     0.044942
# Attr 12    32.891367
# dtype: float64

# %%
total = Quantitative_scales.isnull().sum().sort_values(ascending=False)
percent = (Quantitative_scales.isnull().sum()/Data.shape[0]).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1,join='outer', keys=['Total Missing Count', '% of Total Observations'])
missing_data.index.name ='Quantitative_scales'
missing_data.head(20)
# Out:
#                      Total Missing Count  % of Total Observations
# Quantitative_scales
# Attr 12                                0                      0.0
# Attr 11                                0                      0.0
# Attr 10                                0                      0.0
# Attr 9                                 0                      0.0
# Attr 8                                 0                      0.0
# Attr 7                                 0                      0.0
# Attr 6                                 0                      0.0
# Attr 5                                 0                      0.0
# Attr 4                                 0                      0.0

# %%
        ax = Data['Attr 4'].plot.hist(bins=30)
        ax.set_title('Attr 4 Histogram with 30 bins')
        ax.set_xlabel('Attr 4')
        ax.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
        bx = Data['Attr 5'].plot.hist(bins=30)
        bx.set_title('Attr 5 Histogram with 30 bins')
        bx.set_xlabel('Attr 5')
        bx.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
        cx = Data['Attr 6'].plot.hist(bins=30)
        cx.set_title('Attr 6 Histogram with 30 bins')
        cx.set_xlabel('Attr 6')
        cx.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
        dx = Data['Attr 7'].plot.hist(bins=30)
        dx.set_title('Attr 7 Histogram with 30 bins')
        dx.set_xlabel('Attr 7')
        dx.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
        ex = Data['Attr 8'].plot.hist(bins=30)
        ex.set_title('Attr 8 Histogram with 30 bins')
        ex.set_xlabel('Attr 8')
        ex.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
        fx = Data['Attr 9'].plot.hist(bins=30)
        fx.set_title('Attr 9 Histogram with 30 bins')
        fx.set_xlabel('Attr 9')
        fx.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
        gx = Data['Attr 10'].plot.hist(bins=30)
        gx.set_title('Attr 10 Histogram with 30 bins')
        gx.set_xlabel('Attr 10')
        gx.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
        hx = Data['Attr 11'].plot.hist(bins=30)
        hx.set_title('Attr 11 Histogram with 30 bins')
        hx.set_xlabel('Attr 11')
        hx.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
        ix = Data['Attr 12'].plot.hist(bins=30)
        ix.set_title('Attr 12 Histogram with 30 bins')
        ix.set_xlabel('Attr 12')
        ix.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %%
sns.violinplot(Data["Attr 4"], size = 10)

# %%
sns.violinplot(Data["Attr 5"], size = 10)

# %%
sns.violinplot(Data["Attr 6"], size = 10)

# %%
sns.violinplot(Data["Attr 7"], size = 10)

# %%
sns.violinplot(Data["Attr 8"], size = 10)

# %%
sns.violinplot(Data["Attr 9"], size = 10)

# %%
sns.violinplot(Data["Attr 10"], size = 10)

# %%
sns.violinplot(Data["Attr 11"], size = 10)

# %%
sns.violinplot(Data['Attr 12'], size = 10)

# %%
sns.set(style = "ticks")
columns = ['Attr 4', 'Attr 5', 'Attr 6', 'Attr 7', 'Attr 8', 'Attr 9', 'Attr 10', 'Attr 11', 'Attr 12']
sns.pairplot(Data[columns])
plt.show();

# %%
correlation = Quantitative_scales.corr()
print(correlation);
sns.heatmap(correlation)
# Out:
#            Attr 4    Attr 5    Attr 6    Attr 7    Attr 8    Attr 9   Attr 10  \
# Attr 4   1.000000 -0.657087 -0.095289  0.037024  0.027475  0.026569 -0.001255
# Attr 5  -0.657087  1.000000  0.409578 -0.025654 -0.006643 -0.005474 -0.000344
# Attr 6  -0.095289  0.409578  1.000000 -0.003307  0.016590 -0.010660 -0.043016
# Attr 7   0.037024 -0.025654 -0.003307  1.000000  0.753920  0.602814 -0.233598
# Attr 8   0.027475 -0.006643  0.016590  0.753920  1.000000  0.810710 -0.290803
# Attr 9   0.026569 -0.005474 -0.010660  0.602814  0.810710  1.000000  0.319723
# Attr 10 -0.001255 -0.000344 -0.043016 -0.233598 -0.290803  0.319723  1.000000
# Attr 11 -0.028411  0.006871 -0.012109 -0.754148 -0.996502 -0.792103  0.319723
# Attr 12 -0.062435  0.028746 -0.022716  0.013935  0.025331  0.027283  0.008159
#
#           Attr 11   Attr 12
# Attr 4  -0.028411 -0.062435
# Attr 5   0.006871  0.028746
# Attr 6  -0.012109 -0.022716
# Attr 7  -0.754148  0.013935
# Attr 8  -0.996502  0.025331
# ...

# %%
covariance = Quantitative_scales.cov()
print(covariance);
sns.heatmap(covariance)
# Out:
#             Attr 4     Attr 5     Attr 6    Attr 7    Attr 8    Attr 9  \
# Attr 4    2.141800  -3.354807  -0.468733  0.050644  0.025639  0.024794
# Attr 5   -3.354807  12.170549   4.802677 -0.083649 -0.014777 -0.012176
# Attr 6   -0.468733   4.802677  11.297515 -0.010389  0.035556 -0.022847
# Attr 7    0.050644  -0.083649  -0.010389  0.873582  0.449325  0.359268
# Attr 8    0.025639  -0.014777   0.035556  0.449325  0.406600  0.329634
# Attr 9    0.024794  -0.012176  -0.022847  0.359268  0.329634  0.406600
# Attr 10  -0.001171  -0.000765  -0.092195 -0.139221 -0.118240  0.129999
# Attr 11  -0.026513   0.015285  -0.025952 -0.449461 -0.405178 -0.322069
# Attr 12 -44.878703  49.254652 -37.501364  6.397180  7.933294  8.544566
#
#           Attr 10   Attr 11        Attr 12
# Attr 4  -0.001171 -0.026513     -44.878703
# Attr 5  -0.000765  0.015285      49.254652
# Attr 6  -0.092195 -0.025952     -37.501364
# Attr 7  -0.139221 -0.449461       6.397180
# ...
